# %% [markdown]
# <a href="https://colab.research.google.com/github/LuthfiDffa/CheckPoint-1/blob/main/Checkpoint_2_Luthfi_Daffa_Purbaya_2409116102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAMA: LUTHFI DAFFA PURBAYA
#
# NIM: 2409116102

# %% [markdown]
# ## **DATA UNDERSTANDING**

# %% [markdown]
# # SUMBER DATA

# %% [markdown]
# Dataset yang digunakan dalam analisis ini adalah "Amazon Prime Movies And Tv Show" yang diperoleh dari Kaggle. Dataset ini berisi informasi mengenai merek kosmetik, produk, dan variasi shade makeup yang tersedia.
#
# Sumber dataset: https://www.kaggle.com/datasets/shivamb/amazon-prime-movies-and-tv-shows

# %% [markdown]
# # STRUKTUR DATA

# %% [markdown]
# Dataset ini memiliki beberapa kolom utama, antara lain:
#
# * show_id: ID unik untuk setiap film atau acara TV.
#
# * type: Jenis konten, apakah "Movie" (Film) atau "TV Show" (Acara TV)
#
# * tittle: Judul film atau acara TV
#
# * director: Nama sutradara film atau acara TV.
#
# * cast: Daftar aktor atau aktris yang terlibat dalam film atau acara TV.
#
# * country: Negara asal produksi film atau acara TV.
#
# * date_added: Tanggal ketika film atau acara TV ditambahkan ke Amazon Prime.
#
# * release_year: Tahun rilis Film atau Acara TV.
#
# * rating: Rating usia yang ditetapkan untuk film atau acara TV.
#
# * duration: Durasi Film atau Acara TV
#
# * listed_in: Genre atau kategori film atau acara TV
#
# * description: Sinopsis atau deskripsi singkat tentang film atau acara TV.

# %% [markdown]
# # INFORMASI DATA

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/amazon_prime_titles.csv")

df
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %% [markdown]
# # Missing Values

# %% [markdown]
# Melakukan pengecekan missing values perkolom dalam bentuk presentase, guna mendukung pengambilan keputusan pada nilai yang kosong

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        21.545304
# cast            12.753413
# country         93.049235
# date_added      98.396773
# release_year     0.000000
# rating           3.485726
# duration         0.000000
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %% [markdown]
# Melakukan pengecekan nilai kosong pada kolom director

# %%
df[df['director'].isnull()]
# Out:
#      show_id     type                          title director  \
# 17       s18  TV Show                     Zoo Babies      NaN
# 18       s19  TV Show  Zoë Coombs Marr: Bossy Bottom      NaN
# 20       s21  TV Show                     Zoboomafoo      NaN
# 21       s22  TV Show      Zo Zo Zombie: Mini-Series      NaN
# 23       s24  TV Show                   ZeroZeroZero      NaN
# ...      ...      ...                            ...      ...
# 9655   s9656  TV Show          DaFUNdamentals Series      NaN
# 9658   s9659    Movie          12 Dates of Christmas      NaN
# 9661   s9662  TV Show                     Terrahawks      NaN
# 9664   s9665  TV Show                  Planet Patrol      NaN
# 9666   s9667  TV Show        Maradona: Blessed Dream      NaN
#
#                                                    cast country date_added  \
# 17                           Narrator - Gillian Barlett     NaN        NaN
# ...

# %% [markdown]
# Melakukan pengecekan nilai kosong pada kolom cast

# %%
df[df['cast'].isnull()]
# Out:
#      show_id     type                                     title  \
# 20       s21  TV Show                                Zoboomafoo
# 25       s26    Movie                    Zambezi: Force of Life
# 33       s34    Movie           Young Love (at the Sun Factory)
# 34       s35    Movie           Young Love (at Bowery Ballroom)
# 70       s71    Movie          World Inferno Friendship Society
# ...      ...      ...                                       ...
# 9636   s9637    Movie    Pieces of a Dream: A Story of Gambling
# 9637   s9638  TV Show                       Paul Newman Trilogy
# 9645   s9646  TV Show  Let's Go Cozy Coupe! - Cartoons for Kids
# 9647   s9648  TV Show                          Kids In The Hall
# 9658   s9659    Movie                     12 Dates of Christmas
#
#                 director cast country        date_added  release_year rating  \
# 20                   NaN  NaN     NaN               NaN          2001   TV-Y
# ...

# %% [markdown]
# Melakukan pengecekan nilai kosong pada kolom country

# %%
df[df['country'].isnull()]
# Out:
#      show_id     type                          title         director  \
# 16       s17    Movie                       Zoombies     Glenn Miller
# 17       s18  TV Show                     Zoo Babies              NaN
# 18       s19  TV Show  Zoë Coombs Marr: Bossy Bottom              NaN
# 19       s20    Movie                            Zoe    Drake Doremus
# 20       s21  TV Show                     Zoboomafoo              NaN
# ...      ...      ...                            ...              ...
# 9663   s9664    Movie            Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show                  Planet Patrol              NaN
# 9665   s9666    Movie                        Outpost     Steve Barker
# 9666   s9667  TV Show        Maradona: Blessed Dream              NaN
# 9667   s9668    Movie                    Harry Brown    Daniel Barber
#
#                                                    cast country date_added  \
# ...

# %% [markdown]
# melakukan pengecekan nilai kosong pada kolom date_added

# %%
df[df['date_added'].isnull()]
# Out:
#      show_id     type                          title         director  \
# 16       s17    Movie                       Zoombies     Glenn Miller
# 17       s18  TV Show                     Zoo Babies              NaN
# 18       s19  TV Show  Zoë Coombs Marr: Bossy Bottom              NaN
# 19       s20    Movie                            Zoe    Drake Doremus
# 20       s21  TV Show                     Zoboomafoo              NaN
# ...      ...      ...                            ...              ...
# 9663   s9664    Movie            Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show                  Planet Patrol              NaN
# 9665   s9666    Movie                        Outpost     Steve Barker
# 9666   s9667  TV Show        Maradona: Blessed Dream              NaN
# 9667   s9668    Movie                    Harry Brown    Daniel Barber
#
#                                                    cast country date_added  \
# ...

# %% [markdown]
# Melakukan pengecekan nilai kosong pada kolom rating

# %%
df[df['rating'].isnull()]
# Out:
#      show_id     type                  title        director  \
# 0         s1    Movie    The Grand Seduction    Don McKellar
# 2         s3    Movie   Secrets of Deception     Josh Webber
# 3         s4    Movie     Pink: Staying True  Sonia Anderson
# 4         s5    Movie          Monster Maker    Giles Foster
# 5         s6    Movie  Living With Dinosaurs    Paul Weiland
# ...      ...      ...                    ...             ...
# 6010   s6011  TV Show              Hook City             NaN
# 6152   s6153    Movie                Porky's       Bob Clark
# 6295   s6296    Movie     The Healing Garden   Joseph Granda
# 6352   s6353    Movie            Manipulated     Matt Berman
# 7047   s7048    Movie                Ballast    Lance Hammer
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 2     Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# ...

# %% [markdown]
# # Mengatasi Missing Value

# %%
df['director'] = df['director'].fillna(df['director'].dropna().mean())
df['cast'] = df['cast'].fillna(df['cast'].dropna().mean())
df['country'] = df['country'].fillna(df['country'].dropna().mean())
df['date_added'] = df['date_added'].fillna(df['date_added'].dropna().mean())
df['rating'] = df['rating'].fillna(df['rating'].dropna().mean())

# %%
print(df[['director', 'cast', 'country', 'date_added', 'rating']].isnull().sum())
# Out:
# director      2083
# cast          1233
# country       8996
# date_added    9513
# rating         337
# dtype: int64

# %% [markdown]
# # Duplicated Value

# %% [markdown]
# Duplicated Values adalah sebuah kondisi dimana ada data yang muncul beberapa kali dalam satu data set.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %% [markdown]
# # Outliers

# %% [markdown]
# Outliers adalah nilai yang jauh berbeda dari nilai lainnya dalam dataset. Nilai Outlier bisa jauh lebih rendah atau lebih tinggi. Outlier bisa terjadi karena berbagai alasan seperti faktor kesalahan maupun kejadian lain yang tidak terduga.

# %% [markdown]
# melakukan pengecekan outliers

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom         Persentase Outliers
# release_year            11.108813

# %% [markdown]
# melakukan imputasi

# %%
columns_to_impute = ["release_year"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# melakukan pengecekan ulang

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom         Persentase Outliers
# release_year                  0.0

# %%
df
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %% [markdown]
# # Inconsistent Values

# %%
df
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %%
for col in ["title", "director", "release_year"]:
    print(f"Nilai unik dalam {col}:")
    print(df[col].unique())
    print("\n")
# Out:
# Nilai unik dalam title:
# ['The Grand Seduction' 'Take Care Good Night' 'Secrets of Deception' ...
#  'Outpost' 'Maradona: Blessed Dream' 'Harry Brown']
#
#
# Nilai unik dalam director:
# ['Don McKellar' 'Girish Joshi' 'Josh Webber' ...
#  'John-Paul Davidson, Stephen Warbeck' 'Emily Skye' 'Steve Barker']
#
#
# Nilai unik dalam release_year:
# [2014 2018 2017 1989 2016 1994 2020 2019 2008 2001 1991 2005 2015 2011
#  2013 2007 2002 2009 2012 2010 1992 2021 1993 2006 1996 1997 2004 2003
#  2000 1995 1999 1990 1998]

# %%
df["director"] = df["director"].str.lower().str.strip()
df["director"] = df["director"].str.replace(r'[^a-z0-9\s]', '', regex=True)
df["director"] = df["director"].str.title()

# %%
df
# Out:
#      show_id     type                    title        director  \
# 0         s1    Movie      The Grand Seduction    Don Mckellar
# 1         s2    Movie     Take Care Good Night    Girish Joshi
# 2         s3    Movie     Secrets of Deception     Josh Webber
# 3         s4    Movie       Pink: Staying True  Sonia Anderson
# 4         s5    Movie            Monster Maker    Giles Foster
# ...      ...      ...                      ...             ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H Lewis
# 9664   s9665  TV Show            Planet Patrol             NaN
# 9665   s9666    Movie                  Outpost    Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream             NaN
# 9667   s9668    Movie              Harry Brown   Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %% [markdown]
# # Construct Data

# %%
def categorize_year(year):
    if year < 2000:
        return "Old"
    elif 2000 <= year < 2010:
        return "Mid"
    else:
        return "New"

df["Year_Category"] = df["release_year"].apply(categorize_year)

# %%
df["Duration_Minutes"] = df["duration"].str.extract(r'(\d+)').astype(float)

# %%
def popularity_score(rating):
    if rating in ["TV-MA", "R"]:
        return "High"
    elif rating in ["PG-13", "TV-14"]:
        return "Medium"
    else:
        return "Low"

df["Popularity_Score"] = df["rating"].apply(popularity_score)

# %%
print(df.head())
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don Mckellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %% [markdown]
# # Data Reduction

# %%
df = df.drop(["description", "rating"], axis=1)

# %%
df
# Out:
#      show_id     type                    title        director  \
# 0         s1    Movie      The Grand Seduction    Don Mckellar
# 1         s2    Movie     Take Care Good Night    Girish Joshi
# 2         s3    Movie     Secrets of Deception     Josh Webber
# 3         s4    Movie       Pink: Staying True  Sonia Anderson
# 4         s5    Movie            Monster Maker    Giles Foster
# ...      ...      ...                      ...             ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H Lewis
# 9664   s9665  TV Show            Planet Patrol             NaN
# 9665   s9666    Movie                  Outpost    Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream             NaN
# 9667   s9668    Movie              Harry Brown   Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...
