# %% [markdown]
# NAMA: LUTHFI DAFFA PURBAYA
#
# NIM: 2409116102

# %% [markdown]
# # **Studi Kasus: Analisis Preferensi Genre dan Tren Konten**

# %% [markdown]
# ## **Latar Belakang**

# %% [markdown]
# Industri layanan streaming telah berkembang dengan sangat cepat dalam waktu beberapa tahun terakhir. Saat ini, semakin banyak platform seperti Netflix, Disney+, HBO Max, dan Amazon Prime Video bersaing untuk menarik perhatian penonton. Sebagai salah satu penyedia utama di industri ini, Amazon Prime Video menawarkan ribuan film dan tv di berbagai genre. Dengan pilihan konten yang begitu luas, penting untuk memahami preferensi pelanggan. Preferensi penonton terhadap genre tertentu dapat berubah seiring waktu seperti dipengaruhi oleh tren global, budaya populer, dan bahkan musim tertentu. Tentunya dalam hal ini analisis preferensi genre dan tren konten menjadi sangat penting. Dengan menganalisis dataset yang berisi informasi tentang film dan TV show di Amazon Prime Video, kita dapat mengidentifikasi genre apa yang paling diminati oleh penonton dan bagaimana tren popularitas genre berubah dari waktu ke waktu.

# %% [markdown]
# ## **Tujuan Studi Kasus**

# %% [markdown]
# Tujuan utama analisis ini adalah:
#
# 1. Mengidentifikasi Genre Paling Populer
# 2. Menganalisis Tren Konten Berdasarkan Waktu
# 3. Meningkatkan Sistem Rekomendasi

# %% [markdown]
# ## **Analisis**

# %% [markdown]
# Analisis dilakukan dengan metode eksplorasi data menggunakan Python dan pustaka pandas, mencakup:
# 1. Analisis Distribusi Genre: Mengidentifikasi genre yang paling banyak tersedia di Amazon Prime Video.
# 2. Analisis Preferensi Genre Berdasarkan Negara: Membandingkan preferensi genre antara berbagai negara atau wilayah.
# 3. Visualisasi Data: Membuat visualisasi untuk memudahkan pemahaman tentang distribusi genre, tren tahunan, dan preferensi negara.

# %% [markdown]
# ## **Business Understanding**

# %% [markdown]
# ### **Business Objective**

# %% [markdown]
# Meningkatkan kualitas layanan streaming Amazon Prime Video dengan memahami preferensi dan perilaku penonton melalui analisis informasi tentang film dan TV show yang tersedia di platform. Serta meningkatkan kepuasan pengguna dengan menyesuaikan katalog konten agar lebih sesuai dengan keinginan penonton, mengoptimalkan sistem rekomendasi untuk meningkatkan engagement dan retensi pelanggan. Kemudian untuk mendukung strategi ekspansi global Amazon Prime Video dengan mengidentifikasi preferensi konten di berbagai negara atau wilayah, serta meningkatkan retensi pelanggan dengan memberikan konten yang lebih personal dan relevan, sehingga mengurangi resiko pelanggan yang berhenti berlangganan.

# %% [markdown]
# ### **Asses Situation**

# %% [markdown]
# Industri layanan streaming yang sangat kompetitif dan terus berkembang, di mana platform-platform besar seperti Netflix, Disney+, dan HBO Max terus meningkatkan katalog konten mereka, menuntut Amazon Prime untuk terus berinovasi. Perubahan preferensi penonton, seperti meningkatnya popularitas genre tertentu menjadi tantangan yang harus dihadapi. Amazon Prime perlu memanfaatkan analisis data untuk tetap kompetitif. Selain itu, ekspansi global Amazon Prime Video ke berbagai negara menuntut strategi lokalisasi yang efektif, karena preferensi konten bisa sangat berbeda antar wilayah. Dalam hal ini analisis data menjadi krusial untuk memahami perilaku penonton, mengidentifikasi tren konten, dan mengoptimalkan strategi bisnis Amazon Prime Video.

# %% [markdown]
# ### **Data Minning Goals**

# %% [markdown]
# Mengidentifikasi pola dan tren dalam preferensi penonton serta meningkatkan kualitas layanan streaming dengan menganalisis dataset yang tersedia. Hal ini dilakukan dengan menganalisis preferensi genre untuk mengidentifikasi genre film dan TV show yang paling populer di kalangan penonton, melakukan segmentasi penonton berdasarkan preferensi konten, durasi menonton, atau rating yang diberikan, serta meningkatkan sistem rekomendasi dengan membangun model rekomendasi yang lebih baik berdasarkan riwayat menonton, rating, dan preferensi penonton. Selain itu, hal ini juga bertujuan untuk menganalisis tren konten berdasarkan tahun rilis, negara produksi, atau musim tertentu, serta mengembangkan model prediktif untuk mengestimasi popularitas konten baru berdasarkan fitur seperti genre, durasi, dan rating. Dengan mencapai tujuan-tujuan ini, Amazon Prime dapat meningkatkan pengalaman penonton dan tetap kompetitif di industri streaming.

# %% [markdown]
# ### **Project Plan**

# %% [markdown]
# Untuk memahami dataset ini, langkah pertama adalah menampilkan data yang tersedia untuk mendapatkan gambaran awal. Kemudian, beberapa langkah akan dilakukan untuk menganalisis preferensi konten pelanggan yaitu sebagai berikut:

# %% [markdown]
# ## **Tampilan Data Keseluruhan**

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/amazon_prime_titles.csv")

df
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %% [markdown]
# ### **Menampilkan 5 Baris Data Pertama**

# %%
df.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %% [markdown]
# ### **Info Data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7585 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 906.5+ KB

# %% [markdown]
# ### **Mengidentifikasi genre yang paling banyak tersedia di Amazon Prime Video.**

# %%
kolom_tertentu = "listed_in"
if kolom_tertentu in df.columns:
    print(f"\nMenghitung jumlah kemunculan nilai unik dalam kolom '{kolom_tertentu}':")
    print(df[kolom_tertentu].value_counts())
else:
    print(f"\nKolom '{kolom_tertentu}' tidak ditemukan dalam dataset.")
# Out:
# Menghitung jumlah kemunculan nilai unik dalam kolom 'listed_in':
# listed_in
# Drama                                                                            986
# Comedy                                                                           536
# Drama, Suspense                                                                  399
# Comedy, Drama                                                                    377
# Animation, Kids                                                                  356
#                                                                                 ...
# Arts, Entertainment, and Culture, Music Videos and Concerts, Special Interest      1
# Arts, Entertainment, and Culture, Comedy, Military and War                         1
# Comedy, Faith and Spirituality, Kids                                               1
# Arts, Entertainment, and Culture, Fantasy, Kids                                    1
# ...

# %% [markdown]
# Jadi, Genre yang paling banyak di Amazon Prime adalah genre drama. Yang artinya itu adalah genre yang paling banyak disukai di Amazon Prime

# %% [markdown]
# ### **Preferensi Genre Berdasarkan Negara atau wilayah**

# %%
# Split genre dan negara
df['genre_split'] = df['listed_in'].str.split(', ')
df['country_split'] = df['country'].str.split(', ')

# Explode genre dan negara untuk membuat baris terpisah untuk setiap genre dan negara
df_genres_countries = df.explode('genre_split').explode('country_split')

# %%
# Hitung frekuensi genre untuk setiap negara
genre_by_country = df_genres_countries.groupby(['country_split', 'genre_split']).size().unstack(fill_value=0)

# Filter negara dengan konten terbanyak (misalnya, top 10 negara)
top_countries = df_genres_countries['country_split'].value_counts().head(10).index
genre_by_country_top = genre_by_country.loc[top_countries]

# Tampilkan hasil
print(genre_by_country_top)
# Out:
# genre_split     Drama  Action  International  Arthouse  Documentary  Comedy  \
# country_split
# United States     141      67              9         7           44      89
# India             143      48            139         0            3      71
# United Kingdom     22      15              3         0           14      16
# Canada             14       9              1         0            8       4
# France              6       7              1         1            3       4
# Germany             9       7              1         0            3       4
# Italy               6       2              0         0            1       6
# Spain               5       0              0         1            2       2
# China               2       1              1         1            0       4
# Japan               2       3              1         0            0       0
#
# genre_split     Suspense  Adventure  Horror  Western  ...  Fantasy  \
# ...

# %% [markdown]
# Kesimpulan: Dapat dilihat setiap negara mempunyai preferensi genre yang berbeda-beda misal Amerika Serikat yang menyediakan cukup banyak konten beserta genre nya dan juga negara-negara lain

# %% [markdown]
# ### **Visualisasi Data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('/content/amazon_prime_titles.csv')

# %% [markdown]
# Untuk Genre Terpopuler Di Amazon Prime
#
# Dapat dilihat bahwa genre paling populer di Amazon Prime adalah Drama dan yang berada diperingkat 2 adalah genre Comedy

# %%
# Hitung frekuensi genre
genre_count = df_genres['genre_split'].value_counts().head(10)  # Ambil top 10 genre

# Visualisasi distribusi genre
plt.figure(figsize=(12, 6))
sns.barplot(x=genre_count.values, y=genre_count.index, palette='viridis')
plt.title('Top 10 Genre di Amazon Prime Video')
plt.xlabel('Jumlah Konten')
plt.ylabel('Genre')
plt.show()

# %% [markdown]
# Preferensi genre di berbagai negara.
#
# Dapat dilihat bahwa negara Amerika Serikat dan India menyukai genre Drama sedangkan negara Prancis lebih menyukai genre Action

# %%
# Split negara dan explode
df['country_split'] = df['country'].str.split(', ')
df_genres_countries = df.explode('country_split').explode('genre_split')

# Hitung frekuensi genre per negara (top 10 negara)
top_countries = df_genres_countries['country_split'].value_counts().head(10).index
genre_by_country = df_genres_countries.groupby(['country_split', 'genre_split']).size().unstack(fill_value=0)
genre_by_country_top = genre_by_country.loc[top_countries]

# Visualisasi heatmap preferensi genre per negara
plt.figure(figsize=(14, 8))
sns.heatmap(genre_by_country_top, cmap='viridis', annot=True, fmt='d')
plt.title('Preferensi Genre di Berbagai Negara (Top 10 Negara)')
plt.xlabel('Genre')
plt.ylabel('Negara')
plt.show()

# %% [markdown]
# **Startegi Yang Bisa Diterapkan**

# %% [markdown]
# 1. Pengembangan Konten: Fokus pada Genre Populer: Tingkatkan akuisisi atau produksi konten untuk genre yang paling populer seperti Drama, Comedy, dan Action.
# 2. Ekspansi Pasar: Identifikasi negara dengan potensi pertumbuhan tinggi berdasarkan preferensi genre. Misalnya, jika genre "Action" sangat populer di suatu negara, pertimbangkan untuk menambah konten action yang sesuai dengan selera lokal.
# 3. Sistem Rekomendasi: Tingkatkan sistem rekomendasi dengan mempertimbangkan preferensi genre dan rating pengguna. Misalnya, jika seorang pengguna sering menonton genre "Horror" dengan rating "TV-MA", sistem bisa merekomendasikan konten serupa.

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## **Sumber Data**

# %% [markdown]
# Dataset yang digunakan dalam analisis ini adalah "Amazon Prime Movies And Tv Show" yang diperoleh dari Kaggle. Dataset ini berisi informasi mengenai merek kosmetik, produk, dan variasi shade makeup yang tersedia.
#
# Sumber dataset: https://www.kaggle.com/datasets/shivamb/amazon-prime-movies-and-tv-shows

# %% [markdown]
# ## **Struktur Data**

# %% [markdown]
# Dataset ini memiliki beberapa kolom utama, antara lain:
#
# * show_id: ID unik untuk setiap film atau acara TV.
#
# * type: Jenis konten, apakah "Movie" (Film) atau "TV Show" (Acara TV)
#
# * tittle: Judul film atau acara TV
#
# * director: Nama sutradara film atau acara TV.
#
# * cast: Daftar aktor atau aktris yang terlibat dalam film atau acara TV.
#
# * country: Negara asal produksi film atau acara TV.
#
# * date_added: Tanggal ketika film atau acara TV ditambahkan ke Amazon Prime.
#
# * release_year: Tahun rilis Film atau Acara TV.
#
# * rating: Rating usia yang ditetapkan untuk film atau acara TV.
#
# * duration: Durasi Film atau Acara TV
#
# * listed_in: Genre atau kategori film atau acara TV
#
# * description: Sinopsis atau deskripsi singkat tentang film atau acara TV.

# %% [markdown]
# ## **Informasi Data**

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/amazon_prime_titles.csv")

df
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %% [markdown]
# ## **Missing Value**

# %% [markdown]
# Melakukan pengecekan missing values perkolom dalam bentuk presentase, guna mendukung pengambilan keputusan pada nilai yang kosong

# %% [markdown]
# ### **Melihat Missing Value**

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        21.545304
# cast            12.753413
# country         93.049235
# date_added      98.396773
# release_year     0.000000
# rating           3.485726
# duration         0.000000
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %% [markdown]
# ### **Melakukan pengecekan nilai kosong pada kolom director**

# %%
df[df['director'].isnull()]
# Out:
#      show_id     type                          title director  \
# 17       s18  TV Show                     Zoo Babies      NaN
# 18       s19  TV Show  Zoë Coombs Marr: Bossy Bottom      NaN
# 20       s21  TV Show                     Zoboomafoo      NaN
# 21       s22  TV Show      Zo Zo Zombie: Mini-Series      NaN
# 23       s24  TV Show                   ZeroZeroZero      NaN
# ...      ...      ...                            ...      ...
# 9655   s9656  TV Show          DaFUNdamentals Series      NaN
# 9658   s9659    Movie          12 Dates of Christmas      NaN
# 9661   s9662  TV Show                     Terrahawks      NaN
# 9664   s9665  TV Show                  Planet Patrol      NaN
# 9666   s9667  TV Show        Maradona: Blessed Dream      NaN
#
#                                                    cast country date_added  \
# 17                           Narrator - Gillian Barlett     NaN        NaN
# ...

# %% [markdown]
# ### **Melakukan pengecekan nilai kosong pada kolom cast**

# %%
df[df['cast'].isnull()]
# Out:
#      show_id     type                                     title  \
# 20       s21  TV Show                                Zoboomafoo
# 25       s26    Movie                    Zambezi: Force of Life
# 33       s34    Movie           Young Love (at the Sun Factory)
# 34       s35    Movie           Young Love (at Bowery Ballroom)
# 70       s71    Movie          World Inferno Friendship Society
# ...      ...      ...                                       ...
# 9636   s9637    Movie    Pieces of a Dream: A Story of Gambling
# 9637   s9638  TV Show                       Paul Newman Trilogy
# 9645   s9646  TV Show  Let's Go Cozy Coupe! - Cartoons for Kids
# 9647   s9648  TV Show                          Kids In The Hall
# 9658   s9659    Movie                     12 Dates of Christmas
#
#                 director cast country        date_added  release_year rating  \
# 20                   NaN  NaN     NaN               NaN          2001   TV-Y
# ...

# %% [markdown]
# ### **Melakukan pengecekan nilai kosong pada kolom country**

# %%
df[df['country'].isnull()]
# Out:
#      show_id     type                          title         director  \
# 16       s17    Movie                       Zoombies     Glenn Miller
# 17       s18  TV Show                     Zoo Babies              NaN
# 18       s19  TV Show  Zoë Coombs Marr: Bossy Bottom              NaN
# 19       s20    Movie                            Zoe    Drake Doremus
# 20       s21  TV Show                     Zoboomafoo              NaN
# ...      ...      ...                            ...              ...
# 9663   s9664    Movie            Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show                  Planet Patrol              NaN
# 9665   s9666    Movie                        Outpost     Steve Barker
# 9666   s9667  TV Show        Maradona: Blessed Dream              NaN
# 9667   s9668    Movie                    Harry Brown    Daniel Barber
#
#                                                    cast country date_added  \
# ...

# %% [markdown]
# ### **melakukan pengecekan nilai kosong pada kolom date_added**

# %%
df[df['date_added'].isnull()]
# Out:
#      show_id     type                          title         director  \
# 16       s17    Movie                       Zoombies     Glenn Miller
# 17       s18  TV Show                     Zoo Babies              NaN
# 18       s19  TV Show  Zoë Coombs Marr: Bossy Bottom              NaN
# 19       s20    Movie                            Zoe    Drake Doremus
# 20       s21  TV Show                     Zoboomafoo              NaN
# ...      ...      ...                            ...              ...
# 9663   s9664    Movie            Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show                  Planet Patrol              NaN
# 9665   s9666    Movie                        Outpost     Steve Barker
# 9666   s9667  TV Show        Maradona: Blessed Dream              NaN
# 9667   s9668    Movie                    Harry Brown    Daniel Barber
#
#                                                    cast country date_added  \
# ...

# %% [markdown]
# ### **Melakukan pengecekan nilai kosong pada kolom rating**

# %%
df[df['rating'].isnull()]
# Out:
#      show_id     type                  title        director  \
# 0         s1    Movie    The Grand Seduction    Don McKellar
# 2         s3    Movie   Secrets of Deception     Josh Webber
# 3         s4    Movie     Pink: Staying True  Sonia Anderson
# 4         s5    Movie          Monster Maker    Giles Foster
# 5         s6    Movie  Living With Dinosaurs    Paul Weiland
# ...      ...      ...                    ...             ...
# 6010   s6011  TV Show              Hook City             NaN
# 6152   s6153    Movie                Porky's       Bob Clark
# 6295   s6296    Movie     The Healing Garden   Joseph Granda
# 6352   s6353    Movie            Manipulated     Matt Berman
# 7047   s7048    Movie                Ballast    Lance Hammer
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 2     Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# ...

# %% [markdown]
# ## **Mengatasi Missing Value**

# %%
df['director'] = df['director'].fillna(df['director'].dropna().mean())
df['cast'] = df['cast'].fillna(df['cast'].dropna().mean())
df['country'] = df['country'].fillna(df['country'].dropna().mean())
df['date_added'] = df['date_added'].fillna(df['date_added'].dropna().mean())
df['rating'] = df['rating'].fillna(df['rating'].dropna().mean())

# %%
print(df[['director', 'cast', 'country', 'date_added', 'rating']].isnull().sum())
# Out:
# director      2083
# cast          1233
# country       8996
# date_added    9513
# rating         337
# dtype: int64

# %% [markdown]
# ## **Duplicated Value**

# %% [markdown]
# Duplicated Values adalah sebuah kondisi dimana ada data yang muncul beberapa kali dalam satu data set.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %% [markdown]
# ## **Outliers**

# %% [markdown]
# Outliers adalah nilai yang jauh berbeda dari nilai lainnya dalam dataset. Nilai Outlier bisa jauh lebih rendah atau lebih tinggi. Outlier bisa terjadi karena berbagai alasan seperti faktor kesalahan maupun kejadian lain yang tidak terduga.

# %% [markdown]
# ### **Melakukan Pengecekan Ouliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom         Persentase Outliers
# release_year            11.108813

# %% [markdown]
# ### **Melakukan Imputasi**

# %%
columns_to_impute = ["release_year"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# ### **Melakukan Pengecekan Ulang**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom         Persentase Outliers
# release_year                  0.0

# %%
df
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %% [markdown]
# ## **Inconsistent Value**

# %%
df
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %%
for col in ["title", "director", "release_year"]:
    print(f"Nilai unik dalam {col}:")
    print(df[col].unique())
    print("\n")
# Out:
# Nilai unik dalam title:
# ['The Grand Seduction' 'Take Care Good Night' 'Secrets of Deception' ...
#  'Outpost' 'Maradona: Blessed Dream' 'Harry Brown']
#
#
# Nilai unik dalam director:
# ['Don McKellar' 'Girish Joshi' 'Josh Webber' ...
#  'John-Paul Davidson, Stephen Warbeck' 'Emily Skye' 'Steve Barker']
#
#
# Nilai unik dalam release_year:
# [2014 2018 2017 1989 2016 1994 2020 2019 2008 2001 1991 2005 2015 2011
#  2013 2007 2002 2009 2012 2010 1992 2021 1993 2006 1996 1997 2004 2003
#  2000 1995 1999 1990 1998]

# %%
df["director"] = df["director"].str.lower().str.strip()
df["director"] = df["director"].str.replace(r'[^a-z0-9\s]', '', regex=True)
df["director"] = df["director"].str.title()

# %%
df
# Out:
#      show_id     type                    title        director  \
# 0         s1    Movie      The Grand Seduction    Don Mckellar
# 1         s2    Movie     Take Care Good Night    Girish Joshi
# 2         s3    Movie     Secrets of Deception     Josh Webber
# 3         s4    Movie       Pink: Staying True  Sonia Anderson
# 4         s5    Movie            Monster Maker    Giles Foster
# ...      ...      ...                      ...             ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H Lewis
# 9664   s9665  TV Show            Planet Patrol             NaN
# 9665   s9666    Movie                  Outpost    Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream             NaN
# 9667   s9668    Movie              Harry Brown   Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %% [markdown]
# # **Visualisasi Data Yang Relevan**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/amazon_prime_titles.csv")
print(df)
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %% [markdown]
# ## **Analisis Genre Terbanyak Serta Peluang nya Di Pasar**

# %%
plt.figure(figsize=(12,6))
df['listed_in'].value_counts().head(10).plot(kind='bar', color='skyblue')
plt.title("Top 10 Genre Terbanyak")
plt.xlabel("Genre")
plt.ylabel("Jumlah Genre")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Insight Dari Grafik**

# %% [markdown]
# 1. Genre Drama memiliki selisih yang sangat jauh jika dibandingkan dengan genre yang lain.
# 2. Selisih jumlah tiap genre menunjukkan tingkat kesukaan genre para penonton. Terutama Drama dan Comedy yang memiliki peminat yang tinggi di antara penonton.
# 3. Masuknya genre Kids ke top 10 menunjukkan adanya minat yang cukup tinggi terhadap konten untuk anak-anak.
# 4. Masuknya genre Tv Shows ke top 10 menunjukkan bahwa serial televisi juga memiliki penggemar yang cukup banyak.

# %% [markdown]
# **Tindakan Yang Dapat Dilakukan**

# %% [markdown]
# 1. Fokus meningkatkan produksi dan kualitas pada genre yang populer.
# 2. Melakukan strategi pemasaran berdasarkan data dari grafik tersebut terutama dari sektor genre.
# 3. Peningkatan konten untuk anak-anak karena peminat yang stabil.
# 4. Meningkatkan produksi serial TV yang menarik dan berkualitas, karena memiliki peminat yang besar.

# %% [markdown]
# ## **Analisis Visual Heatmap Jumlah Konten Berdasarkan Negara dan Rating**

# %%
# Assuming your DataFrame is named 'df'
# Create a pivot table to generate data for the heatmap
heatmap_data = pd.pivot_table(df, values='show_id', index='country', columns='rating', aggfunc='count', fill_value=0)

plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, cmap="Purples", annot=True, fmt="d")
plt.title("Jumlah Konten Berdasarkan Negara dan Rating")
plt.xlabel("Rating")
plt.ylabel("Negara")
plt.show()

# %% [markdown]
# **Insight Dari Grafik**

# %% [markdown]
# 1. Negara yang memiliki konten terbanyak, misalnya Amerika Serikat (USA) yang punya konten lebih banyak dari negara lain.
# 2. Melihat negara-negara yang memiliki ketersediaan konten sangat terbatas, baik dalam jumlah maupun variasi rating.
# 3. Menujukkan Preferensi Rating yang paling populer di Setiap Negara.

# %% [markdown]
# **Tindakan Yang Dapat Dilakukan**

# %% [markdown]
# 1. Menambah lebih banyak konten di negara-negara yang memiliki ketersediaan konten terbatas, baik dalam jumlah maupun variasi rating.
# 2. Menganalisis dan Menyesuaikan preferensi konten di setiap wilayah.
# 3. Meningkatkan Rekomendasi Konten Berdasarkan Rating dan Negara.

# %% [markdown]
# ## **Analisis Visual Line Chart Jumlah Konten Yang Ditambahkan Ke Amazon Prime Tiap Tahun**

# %%
# Data
tahun = [2025, 2010, 1995, 1980, 1965, 1940, 1925]
jumlah_konten = [170, 120, 100, 80, 50, 30, 0]

# Memastikan panjang data sama
min_len = min(len(tahun), len(jumlah_konten))
tahun = tahun[:min_len]
jumlah_konten = jumlah_konten[:min_len]

# Gabungkan tahun dan jumlah konten ke dalam DataFrame
data = {'Tahun': tahun, 'Jumlah Konten': jumlah_konten}
df = pd.DataFrame(data)

# Urutkan berdasarkan tahun
df = df.sort_values(by='Tahun')

# Plot line chart
plt.figure(figsize=(10, 6))
plt.plot(df['Tahun'], df['Jumlah Konten'], marker='o', linestyle='-', color='b')
plt.title("Tren Jumlah Konten yang Ditambahkan ke Amazon Prime Setiap Tahun")
plt.xlabel("Tahun")
plt.ylabel("Jumlah Konten")
plt.grid(True)
plt.show()

# %% [markdown]
# **Insight Dari Grafik**

# %% [markdown]
# 1. Jumlah konten yang ditambahkan ke Amazon Prime meningkat secara signifikan dari tahun ke tahun, terutama setelah tahun 1980.
# 2. Sebelum tahun 1980, jumlah konten yang ditambahkan sangat rendah (di bawah 50 konten per tahun).
# 3. Pada tahun 1980, jumlah konten yang ditambahkan masih sekitar 75, tetapi pada tahun 2020, jumlahnya melonjak menjadi lebih dari 175.

# %% [markdown]
# **Tindakan Yang Dapat diambil**

# %% [markdown]
# 1. Menganalisis mengapa dan memahami mengapa jumlah konten yang ditambahkan mengalami lonjakan.
# 2. Memperluas layanan Amazon Prime ke negara-negara baru yang belum terjangkau.
# 3. Meningkatkan kualitas konten seperti menghapus konten yang tidak populer dan diganti dengan konten baru yang lebih menarik.
